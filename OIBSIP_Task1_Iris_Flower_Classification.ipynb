# %% [markdown]
# ## Name: Sagar Suryakant Dhuri
# ## Task 1: Iris Flower Classification

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
from sklearn.datasets import load_iris
iris=load_iris()

# %% [markdown]
# ## Importing URL

# %%
iris=pd.read_csv('C:/Users/Admin/OneDrive/Desktop/Internship task 1/iris.data.csv')

# %% [markdown]
# ## Displaying Datasets

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.isnull().any()
# Out:
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Visualization

# %%
corr=iris.corr() 
plt.figure(figsize=(20,8))
sns.heatmap(corr,annot=True,cmap='Blues',linewidth=1,linecolor='Black') 
plt.title("Correlation HeatMap Between Varibale") 
plt.xticks(rotation=90)
# Out:
# (array([0.5, 1.5, 2.5, 3.5]),
#  [Text(0.5, 0, 'SepalLengthCm'),
#   Text(1.5, 0, 'SepalWidthCm'),
#   Text(2.5, 0, 'PetalLengthCm'),
#   Text(3.5, 0, 'PetalWidthCm')])

# %%
sns.pairplot(iris, hue='Species',palette='rocket_r')

# %%
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=iris,size=9)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(iris["SepalLengthCm"])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SepalLengthCm'>

# %%
data=[1,2,3,4,5]
labels=["5.1","4.9","4.7","4.6","5.0"] 
plt.pie(data,labels=labels,autopct='%.0f%%',explode=[0,0,0,0,0.3])
# Out:
# ([<matplotlib.patches.Wedge at 0x1a92e58ab80>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, '5.1'),
#   Text(0.7360436312779136, 0.817459340184711, '4.9'),
#   Text(-0.33991877217145816, 1.046162142464278, '4.7'),
#   Text(-1.0759623315431446, -0.2287029975759841, '4.6'),
#   Text(0.7000002459522071, -1.212435423297608, '5.0')],
#  [Text(0.5868885590776565, 0.12474702090131072, '7%'),
#   Text(0.4014783443334074, 0.4458869128280241, '13%'),
#   Text(-0.18541023936624987, 0.5706338958896061, '20%'),
#   Text(-0.5868885444780788, -0.12474708958690041, '27%'),
#   Text(0.450000158112133, -0.7794227721198907, '33%')])

# %%
fig,ax=plt.subplots(figsize=(20,10))
ax.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
ax.set_xlabel('SL')
ax.set_ylabel('PL')
plt.show()

# %%
sns.lineplot(x='SepalWidthCm',y='PetalWidthCm',hue='Species',data=iris)
plt.legend()
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X=iris.drop(['Species','SepalWidthCm'],axis=1) 
Y=iris['Species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression 
classifier = LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Making Predictions

# %%
print(X_test)
predictions=dtree.predict(X_test)
predictions
# Out:
#      SepalLengthCm  PetalLengthCm  PetalWidthCm
# 19             5.1            1.5           0.3
# 48             5.3            1.5           0.2
# 106            4.9            4.5           1.7
# 96             5.7            4.2           1.3
# 125            7.2            6.0           1.8
# 11             4.8            1.6           0.2
# 26             5.0            1.6           0.4
# 141            6.9            5.1           2.3
# 7              5.0            1.5           0.2
# 74             6.4            4.3           1.3
# 111            6.4            5.3           1.9
# 119            6.0            5.0           1.5
# 49             5.0            1.4           0.2
# 81             5.5            3.7           1.0
# 18             5.7            1.7           0.3
# 0              5.1            1.4           0.2
# 57             4.9            3.3           1.0
# 60             5.0            3.5           1.0
# 6              4.6            1.4           0.3
# ...

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.82      1.00      0.90         9
#  Iris-virginica       1.00      0.82      0.90        11
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.94      0.93        30
#    weighted avg       0.95      0.93      0.93        30

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  2  9]]

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression() 
reg.fit(iris[['SepalLengthCm']],iris.SepalWidthCm)
# Out:
# LinearRegression()

# %%
plt.scatter(iris.SepalLengthCm,iris.SepalWidthCm,color='purple') 
plt.plot(iris.SepalLengthCm,reg.predict(iris[['SepalLengthCm']]),color='b')

# %%
# Thank You
